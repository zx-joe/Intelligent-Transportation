# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1,2"

# %%
# !python train.py --lr=1e-3 --momentum=0.95 --epochs=11 --lr-decay 60 70 \
--batch-size=16 --basenet=resnet50block5 --head-quad=1 --headnets pif1 \
--square-edge=401 --regression-loss=laplace --lambdas 30 2 1 \
--freeze-base=1 --crop-fraction=0.5
# Out:
# INFO:root:{'type': 'process', 'argv': ['train.py', '--lr=1e-3', '--momentum=0.95', '--epochs=11', '--lr-decay', '60', '70', '--batch-size=16', '--basenet=resnet50block5', '--head-quad=1', '--headnets', 'pif1', '--square-edge=401', '--regression-loss=laplace', '--lambdas', '30', '2', '1', '--freeze-base=1', '--crop-fraction=0.5'], 'args': {'debug': False, 'checkpoint': None, 'dilation': None, 'dilation_end': None, 'basenet': 'resnet50block5', 'headnets': ['pif1'], 'pretrained': True, 'head_dropout': 0.0, 'head_quad': 1, 'head_kernel_size': 1, 'head_padding': 0, 'head_dilation': 1, 'r_smooth': 0.0, 'regression_loss': 'laplace', 'background_weight': 1.0, 'paf_multiplicity_correction': False, 'paf_independence_scale': 3.0, 'paf_min_size': 3, 'paf_fixed_size': False, 'paf_aspect_ratio': 0.0, 'pif_side_length': 4, 'momentum': 0.95, 'beta2': 0.999, 'adam_eps': 1e-06, 'nesterov': True, 'weight_decay': 0.0, 'adam': False, 'amsgrad': False, 'lr': 0.001, 'lr_decay': [60, 70], 'lr_burn_in_epochs
# ...

# %%
# %matplotlib inline

# %%
! python predict.py \
--checkpoint outputs/resnet50block5-pif1-edge401-190522-103822.pkl.epoch008 test/2.jpg \
--show --pif-fixed-scale=1.0 --instance-threshold=0.0

# %%
a = [1,2,3]

# %%
a+a
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a =a+a

# %%
a
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a+a
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]
