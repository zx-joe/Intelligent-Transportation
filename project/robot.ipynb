# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
os.environ["CUDA_VISIBLE_DEVICES"]
# Out:
# '1'

# %%
! python test.py --ip-address 128.179.179.27
# Out:
# # Creating socket
# # Getting remote IP address
# # Connecting to server, 128.179.179.27 (128.179.179.27)
# : cannot connect to X server

# %%
! adb connect 128.179.179.27
# Out:
# /bin/sh: 1: adb: not found

# %%
! adb push follow.cfg /sdcard/
# Out:
# /bin/sh: 1: adb: not found

# %%
! python client.py --ip-address 128.179.179.27 --checkpoint outputs/resnet50block5-pif1-edge401-190528-233721.pkl.epoch009
# Out:
# # Creating socket
# # Getting remote IP address
# # Connecting to server, 128.179.179.27 (128.179.179.27)
# nn processing time 0.018285036087036133
# target_intensities 0.0008959770202636719
# seeds 0 0.002629995346069336
# keypoint sets 0 0.0026535987854003906
# annotations 0 0.0038537979125976562
# BBOX: [40.0, 30.0, 0, 0]
# BBOX_label: [0]
# nn processing time 0.01249241828918457
# target_intensities 0.0006422996520996094
# seeds 0 0.0007829666137695312
# keypoint sets 0 0.0008001327514648438
# annotations 0 0.0015673637390136719
# BBOX: [40.0, 30.0, 0, 0]
# BBOX_label: [0]
# nn processing time 0.012492179870605469
# target_intensities 0.0005655288696289062
# seeds 0 0.0011873245239257812
# keypoint sets 0 0.0012047290802001953
# annotations 0 0.0018918514251708984
# BBOX: [40.0, 30.0, 0, 0]
# BBOX_label: [0]
# nn processing time 0.012482166290283203
# target_intensities 0.0005462169647216797
# seeds 0 0.0007171630859375
# keypoint sets 0 0.0007338523864746094
# ...
