# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as utils
from data_utils import load_CIFAR10

import helper

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = './data/cifar-10-batches-py'
    X_train, y_train = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    
    return X_train, y_train, X_val, y_val


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)

X_train, y_train = torch.from_numpy(X_train).type(torch.FloatTensor), torch.from_numpy(y_train).type(torch.LongTensor)
X_val, y_val = torch.from_numpy(X_val).type(torch.FloatTensor), torch.from_numpy(y_val).type(torch.LongTensor)

traindataset = utils.TensorDataset(X_train, y_train)
trainloader = utils.DataLoader(traindataset, batch_size=64, shuffle=True)

valdataset = utils.TensorDataset(X_val, y_val)
valloader = utils.DataLoader(valdataset, batch_size=64, shuffle=True)
# Out:
# Files already downloaded and verified
# Train data shape:  (49000, 3, 32, 32)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3, 32, 32)
# Validation labels shape:  (1000,)

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        '''
        self.conv1 = torch.nn.Conv2d(3, 32, kernel_size=5)
        self.conv2 = torch.nn.Conv2d(32, 32, kernel_size=5)
        self.conv3 = torch.nn.Conv2d(32, 64, kernel_size=2)
        self.fc1 = torch.nn.Linear(9 * 64, 200)
        self.fc2 = torch.nn.Linear(200, 10)
        '''
        self.conv64 = torch.nn.Conv2d(n_input_channels, 64, kernel_size=3)
        self.conv128 = torch.nn.Conv2d(64, 128,kernel_size=3)
        self.conv256_1 = torch.nn.Conv2d(128, 256, kernel_size=3)
        self.conv256_2 = torch.nn.Conv2d(256, 256, kernel_size=5, padding=1)
        self.bn64 = torch.nn.BatchNorm2d(64)
        self.bn128 = torch.nn.BatchNorm2d(128)
        self.bn256 = torch.nn.BatchNorm2d(256)
        self.bn512 = torch.nn.BatchNorm2d(512)
        self.conv512_1 = torch.nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.conv512_2 = torch.nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.pool = torch.nn.MaxPool2d(2, 2)
        self.pool_2 = torch.nn.AvgPool2d(1, 1)
        self.fc1 = torch.nn.Linear(256, 64)
        self.fc2 = torch.nn.Linear(64, n_output)
        self.fc = torch.nn.Linear(256, n_output)

    def forward(self, x):
        '''
        x = F.relu(F.max_pool2d(self.conv1(x), kernel_size=2))
        x = F.relu(F.max_pool2d(self.conv2(x), kernel_size=2))
        
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc1(x.view(-1, 3* 32*32)))
        x = self.fc2(x)
        '''
        #x = x.view(x.size(0), -1)
        
        x = self.conv64(x)
        x = F.relu(self.bn64(x))
        
        x = self.pool(x)
        
        x = self.conv128(x)
        x = F.relu(self.bn128(x))
        
        x = self.pool(x)
        
        x = self.conv256_1(x)
        x = F.relu(self.bn256(x))
        x = self.conv256_2(x)
        x = F.relu(self.bn256(x))      
        
        x = self.pool(x)
        
        '''x = self.conv512_1(x)
        x = F.relu(torch.nn.BatchNorm2d(x))
        x = self.conv512_2(x)
        x = F.relu(torch.nn.BatchNorm2d(x))  
        
        x = self.pool(x)
        
        x = self.conv512_2(x)
        x = F.relu(torch.nn.BatchNorm2d(x))
        x = self.conv512_2(x)
        x = F.relu(torch.nn.BatchNorm2d(x))  
        
        x = self.pool(x)'''
        
        x = self.pool_2(x)

        x = x.view(-1, 256) 

        x = self.fc1(x)
        x = self.fc2(x)
        #x = self.fc(x)

        #x = x.view(-1, 16 * 5 * 5)

        return x
 
    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01,momentum=0.9)
#loss_func = torch.nn.CrossEntropyLoss()

epochs = 15
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):
        
        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        #pass
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
        
        
        ################################################################################|
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        #pass
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################
        optimizer.zero_grad()
        
        output = net.forward(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()        
        #loss = criterion(output, labels)
        running_loss += loss.item()
        
        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            #net.eval()
            #total = 0
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):
                outputs = net.predict(images)
                #predicted = net.predict(outputs)
                _, predicted = torch.max(outputs.data, 1)
                total = labels.size(0)
                accuracy += ((predicted == labels).sum().item())/total
                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                #pass
                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################
            
            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
            running_loss = 0
            start = time.time()
# Out:
# D:\python\lib\site-packages\ipykernel_launcher.py:83: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Epoch: 1/15.. Loss: 2.0167.. Test accuracy: 0.3633.. 0.4956 s/batch
# Epoch: 1/15.. Loss: 1.6970.. Test accuracy: 0.3686.. 0.5018 s/batch
# Epoch: 1/15.. Loss: 1.5565.. Test accuracy: 0.4418.. 0.4944 s/batch
# Epoch: 1/15.. Loss: 1.5259.. Test accuracy: 0.4373.. 0.4957 s/batch
# Epoch: 1/15.. Loss: 1.4285.. Test accuracy: 0.4781.. 0.5038 s/batch
# Epoch: 1/15.. Loss: 1.3880.. Test accuracy: 0.4547.. 0.5001 s/batch
# Epoch: 1/15.. Loss: 1.4347.. Test accuracy: 0.5174.. 0.5034 s/batch
# Epoch: 1/15.. Loss: 1.3777.. Test accuracy: 0.5219.. 0.5043 s/batch
# Epoch: 1/15.. Loss: 1.3100.. Test accuracy: 0.5279.. 0.5836 s/batch
# Epoch: 1/15.. Loss: 1.2639.. Test accuracy: 0.5621.. 0.5094 s/batch
# Epoch: 1/15.. Loss: 1.2478.. Test accuracy: 0.5396.. 0.5007 s/batch
# Epoch: 1/15.. Loss: 1.2573.. Test accuracy: 0.5471.. 0.4952 s/batch
# Epoch: 1/15.. Loss: 1.2267.. Test accuracy: 0.5811.. 0.4995 s/batch
# Epoch: 1/15.. Loss: 1.1790.. Test accuracy: 0.5668.. 0.4980 s/batch
# Epoch: 1/15.. Loss: 1.2544.. Test accuracy: 0.5922.. 0.4968 s/batch
# Epoch: 1/15.. Loss: 1.1530.. Test accuracy: 0.5844.. 0.4969 s/batch
# Epoch: 1/15.. Loss: 1.1567.. Test accuracy: 0.6232.. 0.4975 s/batch
# Epoch: 1/15.. Loss: 1.1665.. Test accuracy: 0.6055.. 0.5049 s/batch
# Epoch: 1/15.. Loss: 1.2265.. Test accuracy: 0.6002.. 0.4977 s/batch
# Epoch: 1/15.. Loss: 1.0726.. Test accuracy: 0.6279.. 0.5006 s/batch
# Epoch: 1/15.. Loss: 1.1283.. Test accuracy: 0.6104.. 0.4980 s/batch
# Epoch: 1/15.. Loss: 1.0522.. Test accuracy: 0.6020.. 0.5005 s/batch
# Epoch: 1/15.. Loss: 1.0925.. Test accuracy: 0.6305.. 0.5132 s/batch
# Epoch: 1/15.. Loss: 1.0118.. Test accuracy: 0.6377.. 0.5018 s/batch
# Epoch: 1/15.. Loss: 1.0244.. Test accuracy: 0.6361.. 0.5069 s/batch
# Epoch: 1/15.. Loss: 1.0958.. Test accuracy: 0.6359.. 0.4956 s/batch
# Epoch: 1/15.. Loss: 0.9890.. Test accuracy: 0.6506.. 0.5003 s/batch
# Epoch: 1/15.. Loss: 1.0036.. Test accuracy: 0.6371.. 0.5224 s/batch
# Epoch: 1/15.. Loss: 1.0493.. Test accuracy: 0.6455.. 0.4960 s/batch
# Epoch: 1/15.. Loss: 1.0095.. Test accuracy: 0.6512.. 0.4938 s/batch
# Epoch: 1/15.. Loss: 0.9488.. Test accuracy: 0.6662.. 0.4982 s/batch
# Epoch: 1/15.. Loss: 0.9936.. Test accuracy: 0.6494.. 0.5002 s/batch
# Epoch: 1/15.. Loss: 0.9792.. Test accuracy: 0.6604.. 0.5045 s/batch
# Epoch: 1/15.. Loss: 1.0023.. Test accuracy: 0.6691.. 0.5057 s/batch
# Epoch: 1/15.. Loss: 0.9530.. Test accuracy: 0.6586.. 0.4972 s/batch
# Epoch: 1/15.. Loss: 0.9880.. Test accuracy: 0.6779.. 0.5047 s/batch
# Epoch: 1/15.. Loss: 1.0101.. Test accuracy: 0.6676.. 0.5034 s/batch
# Epoch: 1/15.. Loss: 0.9926.. Test accuracy: 0.6687.. 0.5192 s/batch
# Epoch: 2/15.. Loss: 0.9372.. Test accuracy: 0.6791.. 0.3518 s/batch
# Epoch: 2/15.. Loss: 0.8950.. Test accuracy: 0.6949.. 0.4988 s/batch
# Epoch: 2/15.. Loss: 0.8723.. Test accuracy: 0.6729.. 0.5345 s/batch
# Epoch: 2/15.. Loss: 0.8769.. Test accuracy: 0.6668.. 0.5096 s/batch
# Epoch: 2/15.. Loss: 0.8278.. Test accuracy: 0.6840.. 0.5149 s/batch
# Epoch: 2/15.. Loss: 0.7763.. Test accuracy: 0.6879.. 0.5201 s/batch
# Epoch: 2/15.. Loss: 0.7753.. Test accuracy: 0.6834.. 0.5113 s/batch
# Epoch: 2/15.. Loss: 0.8642.. Test accuracy: 0.6635.. 0.5121 s/batch
# Epoch: 2/15.. Loss: 0.8528.. Test accuracy: 0.6920.. 0.5090 s/batch
# Epoch: 2/15.. Loss: 0.8928.. Test accuracy: 0.6893.. 0.5092 s/batch
# Epoch: 2/15.. Loss: 0.8767.. Test accuracy: 0.6713.. 0.5093 s/batch
# Epoch: 2/15.. Loss: 0.8317.. Test accuracy: 0.6922.. 0.5076 s/batch
# Epoch: 2/15.. Loss: 0.8555.. Test accuracy: 0.6840.. 0.5111 s/batch
# Epoch: 2/15.. Loss: 0.8670.. Test accuracy: 0.7131.. 0.5129 s/batch
# Epoch: 2/15.. Loss: 0.7683.. Test accuracy: 0.7119.. 0.5022 s/batch
# Epoch: 2/15.. Loss: 0.8287.. Test accuracy: 0.7021.. 0.5066 s/batch
# Epoch: 2/15.. Loss: 0.8352.. Test accuracy: 0.7080.. 0.5021 s/batch
# Epoch: 2/15.. Loss: 0.8245.. Test accuracy: 0.7000.. 0.5007 s/batch
# Epoch: 2/15.. Loss: 0.8055.. Test accuracy: 0.6906.. 0.5015 s/batch
# Epoch: 2/15.. Loss: 0.8337.. Test accuracy: 0.7164.. 0.5096 s/batch
# Epoch: 2/15.. Loss: 0.8437.. Test accuracy: 0.7137.. 0.5035 s/batch
# Epoch: 2/15.. Loss: 0.7574.. Test accuracy: 0.7121.. 0.5032 s/batch
# Epoch: 2/15.. Loss: 0.7944.. Test accuracy: 0.7016.. 0.5025 s/batch
# Epoch: 2/15.. Loss: 0.8039.. Test accuracy: 0.7143.. 0.5061 s/batch
# Epoch: 2/15.. Loss: 0.7886.. Test accuracy: 0.7506.. 0.4981 s/batch
# Epoch: 2/15.. Loss: 0.8023.. Test accuracy: 0.7297.. 0.4988 s/batch
# Epoch: 2/15.. Loss: 0.7586.. Test accuracy: 0.7170.. 0.5046 s/batch
# Epoch: 2/15.. Loss: 0.7725.. Test accuracy: 0.7291.. 0.5097 s/batch
# Epoch: 2/15.. Loss: 0.7812.. Test accuracy: 0.7135.. 0.5015 s/batch
# Epoch: 2/15.. Loss: 0.8156.. Test accuracy: 0.7316.. 0.5013 s/batch
# Epoch: 2/15.. Loss: 0.7671.. Test accuracy: 0.7197.. 0.4999 s/batch
# Epoch: 2/15.. Loss: 0.8654.. Test accuracy: 0.7270.. 0.5058 s/batch
# Epoch: 2/15.. Loss: 0.7847.. Test accuracy: 0.7240.. 0.5092 s/batch
# Epoch: 2/15.. Loss: 0.7455.. Test accuracy: 0.7266.. 0.4975 s/batch
# Epoch: 2/15.. Loss: 0.7393.. Test accuracy: 0.7350.. 0.5050 s/batch
# Epoch: 2/15.. Loss: 0.8025.. Test accuracy: 0.7250.. 0.5014 s/batch
# Epoch: 2/15.. Loss: 0.7752.. Test accuracy: 0.7184.. 0.5020 s/batch
# Epoch: 2/15.. Loss: 0.8107.. Test accuracy: 0.7479.. 0.5010 s/batch
# Epoch: 3/15.. Loss: 0.8160.. Test accuracy: 0.7330.. 0.2014 s/batch
# Epoch: 3/15.. Loss: 0.6153.. Test accuracy: 0.7338.. 0.4993 s/batch
# Epoch: 3/15.. Loss: 0.6367.. Test accuracy: 0.7373.. 0.4980 s/batch
# Epoch: 3/15.. Loss: 0.6305.. Test accuracy: 0.7410.. 0.5008 s/batch
# Epoch: 3/15.. Loss: 0.6075.. Test accuracy: 0.7414.. 0.5017 s/batch
# Epoch: 3/15.. Loss: 0.6540.. Test accuracy: 0.7484.. 0.4998 s/batch
# Epoch: 3/15.. Loss: 0.6072.. Test accuracy: 0.7307.. 0.4994 s/batch
# Epoch: 3/15.. Loss: 0.5898.. Test accuracy: 0.7414.. 0.5025 s/batch
# Epoch: 3/15.. Loss: 0.6919.. Test accuracy: 0.7373.. 0.5098 s/batch
# Epoch: 3/15.. Loss: 0.6659.. Test accuracy: 0.7402.. 0.5021 s/batch
# Epoch: 3/15.. Loss: 0.6888.. Test accuracy: 0.7412.. 0.5085 s/batch
# Epoch: 3/15.. Loss: 0.6077.. Test accuracy: 0.7318.. 0.5041 s/batch
# Epoch: 3/15.. Loss: 0.6649.. Test accuracy: 0.7332.. 0.5021 s/batch
# Epoch: 3/15.. Loss: 0.6498.. Test accuracy: 0.7211.. 0.5067 s/batch
# Epoch: 3/15.. Loss: 0.6656.. Test accuracy: 0.7459.. 0.4995 s/batch
# Epoch: 3/15.. Loss: 0.6441.. Test accuracy: 0.7406.. 0.4940 s/batch
# Epoch: 3/15.. Loss: 0.6422.. Test accuracy: 0.7330.. 0.4955 s/batch
# Epoch: 3/15.. Loss: 0.6326.. Test accuracy: 0.7371.. 0.4948 s/batch
# Epoch: 3/15.. Loss: 0.6745.. Test accuracy: 0.7355.. 0.4958 s/batch
# Epoch: 3/15.. Loss: 0.6807.. Test accuracy: 0.7488.. 0.5003 s/batch
# Epoch: 3/15.. Loss: 0.6648.. Test accuracy: 0.7516.. 0.5095 s/batch
# Epoch: 3/15.. Loss: 0.6498.. Test accuracy: 0.7551.. 0.4959 s/batch
# Epoch: 3/15.. Loss: 0.5803.. Test accuracy: 0.7545.. 0.4968 s/batch
# Epoch: 3/15.. Loss: 0.6166.. Test accuracy: 0.7547.. 0.4981 s/batch
# Epoch: 3/15.. Loss: 0.6476.. Test accuracy: 0.7262.. 0.5024 s/batch
# Epoch: 3/15.. Loss: 0.5982.. Test accuracy: 0.7396.. 0.5093 s/batch
# Epoch: 3/15.. Loss: 0.6653.. Test accuracy: 0.7389.. 0.4998 s/batch
# Epoch: 3/15.. Loss: 0.6582.. Test accuracy: 0.7611.. 0.4949 s/batch
# Epoch: 3/15.. Loss: 0.6696.. Test accuracy: 0.7467.. 0.5077 s/batch
# Epoch: 3/15.. Loss: 0.6127.. Test accuracy: 0.7480.. 0.5082 s/batch
# Epoch: 3/15.. Loss: 0.6463.. Test accuracy: 0.7332.. 0.5067 s/batch
# Epoch: 3/15.. Loss: 0.6384.. Test accuracy: 0.7424.. 0.4960 s/batch
# Epoch: 3/15.. Loss: 0.6474.. Test accuracy: 0.7443.. 0.5014 s/batch
# Epoch: 3/15.. Loss: 0.5983.. Test accuracy: 0.7465.. 0.5009 s/batch
# Epoch: 3/15.. Loss: 0.6434.. Test accuracy: 0.7529.. 0.4975 s/batch
# Epoch: 3/15.. Loss: 0.6323.. Test accuracy: 0.7348.. 0.5019 s/batch
# Epoch: 3/15.. Loss: 0.6412.. Test accuracy: 0.7590.. 0.4953 s/batch
# Epoch: 3/15.. Loss: 0.5955.. Test accuracy: 0.7537.. 0.4979 s/batch
# Epoch: 4/15.. Loss: 0.6315.. Test accuracy: 0.7490.. 0.0494 s/batch
# Epoch: 4/15.. Loss: 0.4923.. Test accuracy: 0.7639.. 0.4998 s/batch
# Epoch: 4/15.. Loss: 0.5011.. Test accuracy: 0.7539.. 0.5031 s/batch
# Epoch: 4/15.. Loss: 0.4511.. Test accuracy: 0.7648.. 0.5009 s/batch
# Epoch: 4/15.. Loss: 0.4737.. Test accuracy: 0.7500.. 0.5035 s/batch
# Epoch: 4/15.. Loss: 0.4310.. Test accuracy: 0.7662.. 0.5094 s/batch
# Epoch: 4/15.. Loss: 0.4895.. Test accuracy: 0.7676.. 0.5109 s/batch
# Epoch: 4/15.. Loss: 0.5010.. Test accuracy: 0.7566.. 0.5134 s/batch
# Epoch: 4/15.. Loss: 0.5530.. Test accuracy: 0.7508.. 0.5194 s/batch
# Epoch: 4/15.. Loss: 0.5470.. Test accuracy: 0.7473.. 0.5167 s/batch
# Epoch: 4/15.. Loss: 0.5295.. Test accuracy: 0.7566.. 0.5161 s/batch
# Epoch: 4/15.. Loss: 0.5157.. Test accuracy: 0.7555.. 0.5315 s/batch
# Epoch: 4/15.. Loss: 0.5027.. Test accuracy: 0.7637.. 0.5212 s/batch
# Epoch: 4/15.. Loss: 0.4997.. Test accuracy: 0.7389.. 0.5196 s/batch
# Epoch: 4/15.. Loss: 0.5329.. Test accuracy: 0.7740.. 0.5585 s/batch
# Epoch: 4/15.. Loss: 0.4780.. Test accuracy: 0.7477.. 0.5244 s/batch
# Epoch: 4/15.. Loss: 0.5166.. Test accuracy: 0.7627.. 0.5393 s/batch
# Epoch: 4/15.. Loss: 0.4977.. Test accuracy: 0.7639.. 0.5216 s/batch
# Epoch: 4/15.. Loss: 0.5003.. Test accuracy: 0.7666.. 0.5226 s/batch
# Epoch: 4/15.. Loss: 0.5421.. Test accuracy: 0.7504.. 0.5328 s/batch
# Epoch: 4/15.. Loss: 0.5319.. Test accuracy: 0.7619.. 0.5252 s/batch
# Epoch: 4/15.. Loss: 0.4759.. Test accuracy: 0.7572.. 0.5231 s/batch
# Epoch: 4/15.. Loss: 0.4780.. Test accuracy: 0.7572.. 0.5328 s/batch
# Epoch: 4/15.. Loss: 0.5510.. Test accuracy: 0.7383.. 0.5573 s/batch
# Epoch: 4/15.. Loss: 0.5295.. Test accuracy: 0.7662.. 0.5336 s/batch
# Epoch: 4/15.. Loss: 0.4654.. Test accuracy: 0.7645.. 0.5299 s/batch
# Epoch: 4/15.. Loss: 0.5099.. Test accuracy: 0.7512.. 0.5298 s/batch
# Epoch: 4/15.. Loss: 0.5199.. Test accuracy: 0.7375.. 0.5260 s/batch
# Epoch: 4/15.. Loss: 0.5538.. Test accuracy: 0.7523.. 0.5300 s/batch
# Epoch: 4/15.. Loss: 0.4944.. Test accuracy: 0.7396.. 0.5247 s/batch
# Epoch: 4/15.. Loss: 0.5355.. Test accuracy: 0.7523.. 0.5312 s/batch
# Epoch: 4/15.. Loss: 0.4923.. Test accuracy: 0.7525.. 0.5285 s/batch
# Epoch: 4/15.. Loss: 0.5238.. Test accuracy: 0.7688.. 0.5319 s/batch
# Epoch: 4/15.. Loss: 0.4975.. Test accuracy: 0.7654.. 0.5321 s/batch
# Epoch: 4/15.. Loss: 0.4804.. Test accuracy: 0.7637.. 0.5348 s/batch
# Epoch: 4/15.. Loss: 0.5457.. Test accuracy: 0.7643.. 0.5285 s/batch
# Epoch: 4/15.. Loss: 0.5319.. Test accuracy: 0.7627.. 0.5639 s/batch
# Epoch: 4/15.. Loss: 0.5674.. Test accuracy: 0.7584.. 0.5500 s/batch
# Epoch: 4/15.. Loss: 0.5393.. Test accuracy: 0.7689.. 0.5314 s/batch
# Epoch: 5/15.. Loss: 0.4634.. Test accuracy: 0.7775.. 0.4502 s/batch
# Epoch: 5/15.. Loss: 0.3433.. Test accuracy: 0.7732.. 0.5327 s/batch
# Epoch: 5/15.. Loss: 0.3319.. Test accuracy: 0.7613.. 0.5335 s/batch
# Epoch: 5/15.. Loss: 0.3600.. Test accuracy: 0.7604.. 0.5442 s/batch
# Epoch: 5/15.. Loss: 0.3610.. Test accuracy: 0.7824.. 0.5325 s/batch
# Epoch: 5/15.. Loss: 0.3676.. Test accuracy: 0.7715.. 0.5487 s/batch
# Epoch: 5/15.. Loss: 0.3342.. Test accuracy: 0.7770.. 0.5425 s/batch
# Epoch: 5/15.. Loss: 0.3754.. Test accuracy: 0.7771.. 0.5428 s/batch
# Epoch: 5/15.. Loss: 0.3554.. Test accuracy: 0.7740.. 0.5426 s/batch
# Epoch: 5/15.. Loss: 0.3709.. Test accuracy: 0.7803.. 0.5442 s/batch
# Epoch: 5/15.. Loss: 0.3792.. Test accuracy: 0.7627.. 0.5410 s/batch
# Epoch: 5/15.. Loss: 0.3814.. Test accuracy: 0.7668.. 0.5426 s/batch
# Epoch: 5/15.. Loss: 0.3472.. Test accuracy: 0.7771.. 0.5466 s/batch
# Epoch: 5/15.. Loss: 0.3682.. Test accuracy: 0.7746.. 0.5420 s/batch
# Epoch: 5/15.. Loss: 0.3896.. Test accuracy: 0.7580.. 0.5455 s/batch
# Epoch: 5/15.. Loss: 0.3848.. Test accuracy: 0.7730.. 0.5480 s/batch
# Epoch: 5/15.. Loss: 0.4116.. Test accuracy: 0.7734.. 0.5510 s/batch
# Epoch: 5/15.. Loss: 0.3941.. Test accuracy: 0.7678.. 0.5539 s/batch
# Epoch: 5/15.. Loss: 0.3991.. Test accuracy: 0.7596.. 0.5523 s/batch
# Epoch: 5/15.. Loss: 0.3981.. Test accuracy: 0.7688.. 0.5448 s/batch
# Epoch: 5/15.. Loss: 0.4107.. Test accuracy: 0.7518.. 0.5494 s/batch
# Epoch: 5/15.. Loss: 0.3932.. Test accuracy: 0.7715.. 0.5642 s/batch
# Epoch: 5/15.. Loss: 0.4034.. Test accuracy: 0.7557.. 0.5607 s/batch
# Epoch: 5/15.. Loss: 0.3823.. Test accuracy: 0.7539.. 0.5661 s/batch
# Epoch: 5/15.. Loss: 0.3777.. Test accuracy: 0.7676.. 0.5446 s/batch
# Epoch: 5/15.. Loss: 0.4311.. Test accuracy: 0.7443.. 0.5484 s/batch
# Epoch: 5/15.. Loss: 0.4201.. Test accuracy: 0.7527.. 0.5486 s/batch
# Epoch: 5/15.. Loss: 0.4276.. Test accuracy: 0.7711.. 0.5476 s/batch
# Epoch: 5/15.. Loss: 0.4192.. Test accuracy: 0.7561.. 0.5457 s/batch
# Epoch: 5/15.. Loss: 0.4426.. Test accuracy: 0.7646.. 0.5596 s/batch
# Epoch: 5/15.. Loss: 0.4149.. Test accuracy: 0.7568.. 0.5446 s/batch
# Epoch: 5/15.. Loss: 0.4276.. Test accuracy: 0.7703.. 0.5555 s/batch
# Epoch: 5/15.. Loss: 0.4244.. Test accuracy: 0.7525.. 0.5456 s/batch
# Epoch: 5/15.. Loss: 0.4631.. Test accuracy: 0.7596.. 0.5445 s/batch
# Epoch: 5/15.. Loss: 0.4093.. Test accuracy: 0.7777.. 0.5500 s/batch
# Epoch: 5/15.. Loss: 0.4206.. Test accuracy: 0.7883.. 0.5443 s/batch
# Epoch: 5/15.. Loss: 0.3844.. Test accuracy: 0.7729.. 0.5578 s/batch
# Epoch: 5/15.. Loss: 0.3875.. Test accuracy: 0.7812.. 0.5553 s/batch
# Epoch: 6/15.. Loss: 0.3908.. Test accuracy: 0.7736.. 0.2762 s/batch
# Epoch: 6/15.. Loss: 0.2841.. Test accuracy: 0.7920.. 0.5534 s/batch
# Epoch: 6/15.. Loss: 0.2789.. Test accuracy: 0.7912.. 0.5541 s/batch
# Epoch: 6/15.. Loss: 0.2233.. Test accuracy: 0.7963.. 0.5622 s/batch
# Epoch: 6/15.. Loss: 0.2455.. Test accuracy: 0.7863.. 0.5549 s/batch
# Epoch: 6/15.. Loss: 0.2276.. Test accuracy: 0.7807.. 0.5620 s/batch
# Epoch: 6/15.. Loss: 0.2269.. Test accuracy: 0.7621.. 0.5592 s/batch
# Epoch: 6/15.. Loss: 0.2281.. Test accuracy: 0.7785.. 0.5604 s/batch
# Epoch: 6/15.. Loss: 0.2696.. Test accuracy: 0.7738.. 0.5576 s/batch
# Epoch: 6/15.. Loss: 0.2416.. Test accuracy: 0.7750.. 0.5567 s/batch
# Epoch: 6/15.. Loss: 0.2860.. Test accuracy: 0.7859.. 0.5597 s/batch
# Epoch: 6/15.. Loss: 0.2906.. Test accuracy: 0.7801.. 0.5658 s/batch
# Epoch: 6/15.. Loss: 0.2824.. Test accuracy: 0.7727.. 0.5704 s/batch
# Epoch: 6/15.. Loss: 0.2849.. Test accuracy: 0.7732.. 0.5667 s/batch
# Epoch: 6/15.. Loss: 0.2670.. Test accuracy: 0.7818.. 0.5645 s/batch
# Epoch: 6/15.. Loss: 0.2718.. Test accuracy: 0.7695.. 0.5606 s/batch
# Epoch: 6/15.. Loss: 0.2593.. Test accuracy: 0.7742.. 0.5645 s/batch
# Epoch: 6/15.. Loss: 0.2867.. Test accuracy: 0.7666.. 0.5625 s/batch
# Epoch: 6/15.. Loss: 0.2819.. Test accuracy: 0.7584.. 0.5771 s/batch
# Epoch: 6/15.. Loss: 0.3137.. Test accuracy: 0.7854.. 0.5710 s/batch
# Epoch: 6/15.. Loss: 0.2769.. Test accuracy: 0.7838.. 0.5750 s/batch
# Epoch: 6/15.. Loss: 0.2830.. Test accuracy: 0.7514.. 0.5685 s/batch
# Epoch: 6/15.. Loss: 0.2725.. Test accuracy: 0.7738.. 0.5777 s/batch
# Epoch: 6/15.. Loss: 0.2797.. Test accuracy: 0.7705.. 0.5721 s/batch
# Epoch: 6/15.. Loss: 0.2860.. Test accuracy: 0.7574.. 0.5698 s/batch
# Epoch: 6/15.. Loss: 0.3143.. Test accuracy: 0.7502.. 0.5732 s/batch
# Epoch: 6/15.. Loss: 0.3032.. Test accuracy: 0.7518.. 0.5732 s/batch
# Epoch: 6/15.. Loss: 0.3462.. Test accuracy: 0.7715.. 0.5866 s/batch
# Epoch: 6/15.. Loss: 0.3110.. Test accuracy: 0.7602.. 0.6322 s/batch
# Epoch: 6/15.. Loss: 0.3357.. Test accuracy: 0.7459.. 0.6022 s/batch
# Epoch: 6/15.. Loss: 0.3062.. Test accuracy: 0.7648.. 0.5819 s/batch
# Epoch: 6/15.. Loss: 0.3217.. Test accuracy: 0.7578.. 0.5880 s/batch
# Epoch: 6/15.. Loss: 0.2945.. Test accuracy: 0.7580.. 0.5780 s/batch
# Epoch: 6/15.. Loss: 0.3633.. Test accuracy: 0.7801.. 0.5854 s/batch
# Epoch: 6/15.. Loss: 0.3185.. Test accuracy: 0.7629.. 0.5862 s/batch
# Epoch: 6/15.. Loss: 0.3275.. Test accuracy: 0.7760.. 0.5827 s/batch
# Epoch: 6/15.. Loss: 0.3211.. Test accuracy: 0.7646.. 0.5832 s/batch
# Epoch: 6/15.. Loss: 0.2914.. Test accuracy: 0.7703.. 0.5800 s/batch
# Epoch: 7/15.. Loss: 0.3085.. Test accuracy: 0.7645.. 0.1155 s/batch
# Epoch: 7/15.. Loss: 0.1763.. Test accuracy: 0.7643.. 0.5760 s/batch
# Epoch: 7/15.. Loss: 0.1704.. Test accuracy: 0.7668.. 0.6259 s/batch
# Epoch: 7/15.. Loss: 0.1652.. Test accuracy: 0.7736.. 0.6223 s/batch
# Epoch: 7/15.. Loss: 0.1516.. Test accuracy: 0.7900.. 0.5687 s/batch
# Epoch: 7/15.. Loss: 0.1561.. Test accuracy: 0.7781.. 0.5440 s/batch
# Epoch: 7/15.. Loss: 0.1437.. Test accuracy: 0.7771.. 0.5405 s/batch
# Epoch: 7/15.. Loss: 0.1640.. Test accuracy: 0.7828.. 0.5388 s/batch
# Epoch: 7/15.. Loss: 0.1518.. Test accuracy: 0.7717.. 0.5851 s/batch
# Epoch: 7/15.. Loss: 0.1910.. Test accuracy: 0.7859.. 0.5727 s/batch
# Epoch: 7/15.. Loss: 0.1730.. Test accuracy: 0.7713.. 0.5513 s/batch
# Epoch: 7/15.. Loss: 0.1631.. Test accuracy: 0.7691.. 0.5246 s/batch
# Epoch: 7/15.. Loss: 0.1777.. Test accuracy: 0.7771.. 0.5281 s/batch
# Epoch: 7/15.. Loss: 0.1727.. Test accuracy: 0.7812.. 0.5827 s/batch
# Epoch: 7/15.. Loss: 0.1846.. Test accuracy: 0.7742.. 0.5576 s/batch
# Epoch: 7/15.. Loss: 0.1930.. Test accuracy: 0.7662.. 0.5147 s/batch
# Epoch: 7/15.. Loss: 0.2100.. Test accuracy: 0.7721.. 0.5087 s/batch
# Epoch: 7/15.. Loss: 0.1949.. Test accuracy: 0.7748.. 0.5129 s/batch
# Epoch: 7/15.. Loss: 0.1739.. Test accuracy: 0.7773.. 0.5420 s/batch
# Epoch: 7/15.. Loss: 0.1917.. Test accuracy: 0.7635.. 0.5299 s/batch
# Epoch: 7/15.. Loss: 0.2242.. Test accuracy: 0.7629.. 0.5039 s/batch
# Epoch: 7/15.. Loss: 0.2299.. Test accuracy: 0.7684.. 0.5302 s/batch
# Epoch: 7/15.. Loss: 0.2451.. Test accuracy: 0.7639.. 0.5361 s/batch
# Epoch: 7/15.. Loss: 0.2568.. Test accuracy: 0.7738.. 0.5400 s/batch
# Epoch: 7/15.. Loss: 0.2478.. Test accuracy: 0.7775.. 0.5614 s/batch
# Epoch: 7/15.. Loss: 0.2351.. Test accuracy: 0.7723.. 0.5151 s/batch
# Epoch: 7/15.. Loss: 0.2353.. Test accuracy: 0.7674.. 0.5083 s/batch
# Epoch: 7/15.. Loss: 0.1969.. Test accuracy: 0.7873.. 0.5101 s/batch
# Epoch: 7/15.. Loss: 0.2384.. Test accuracy: 0.7451.. 0.5542 s/batch
# Epoch: 7/15.. Loss: 0.2451.. Test accuracy: 0.7678.. 0.6279 s/batch
# Epoch: 7/15.. Loss: 0.2564.. Test accuracy: 0.7701.. 0.6153 s/batch
# Epoch: 7/15.. Loss: 0.2087.. Test accuracy: 0.7686.. 0.5356 s/batch
# Epoch: 7/15.. Loss: 0.2581.. Test accuracy: 0.7801.. 0.5062 s/batch
# Epoch: 7/15.. Loss: 0.2192.. Test accuracy: 0.7709.. 0.5109 s/batch
# Epoch: 7/15.. Loss: 0.2468.. Test accuracy: 0.7812.. 0.5122 s/batch
# Epoch: 7/15.. Loss: 0.2351.. Test accuracy: 0.7732.. 0.5371 s/batch
# Epoch: 7/15.. Loss: 0.2565.. Test accuracy: 0.7682.. 0.5404 s/batch
# Epoch: 7/15.. Loss: 0.2534.. Test accuracy: 0.7693.. 0.5509 s/batch
# Epoch: 7/15.. Loss: 0.2401.. Test accuracy: 0.7717.. 0.5715 s/batch
# Epoch: 8/15.. Loss: 0.1577.. Test accuracy: 0.7758.. 0.4784 s/batch
# Epoch: 8/15.. Loss: 0.1426.. Test accuracy: 0.8020.. 0.5305 s/batch
# Epoch: 8/15.. Loss: 0.1134.. Test accuracy: 0.7914.. 0.5669 s/batch
# Epoch: 8/15.. Loss: 0.1105.. Test accuracy: 0.7941.. 0.5446 s/batch
# Epoch: 8/15.. Loss: 0.1352.. Test accuracy: 0.8004.. 0.4981 s/batch
# Epoch: 8/15.. Loss: 0.1213.. Test accuracy: 0.7844.. 0.5004 s/batch
# Epoch: 8/15.. Loss: 0.1213.. Test accuracy: 0.7979.. 0.5229 s/batch
# Epoch: 8/15.. Loss: 0.1298.. Test accuracy: 0.7807.. 0.5013 s/batch
# Epoch: 8/15.. Loss: 0.1301.. Test accuracy: 0.7848.. 0.5160 s/batch
# Epoch: 8/15.. Loss: 0.1373.. Test accuracy: 0.7746.. 0.5138 s/batch
# Epoch: 8/15.. Loss: 0.1307.. Test accuracy: 0.7861.. 0.5042 s/batch
# Epoch: 8/15.. Loss: 0.1292.. Test accuracy: 0.7867.. 0.5130 s/batch
# Epoch: 8/15.. Loss: 0.1291.. Test accuracy: 0.7811.. 0.5056 s/batch
# Epoch: 8/15.. Loss: 0.1158.. Test accuracy: 0.7799.. 0.5009 s/batch
# Epoch: 8/15.. Loss: 0.1109.. Test accuracy: 0.7777.. 0.5279 s/batch
# Epoch: 8/15.. Loss: 0.1134.. Test accuracy: 0.7846.. 0.5099 s/batch
# Epoch: 8/15.. Loss: 0.1077.. Test accuracy: 0.7877.. 0.4975 s/batch
# Epoch: 8/15.. Loss: 0.1199.. Test accuracy: 0.7752.. 0.5178 s/batch
# Epoch: 8/15.. Loss: 0.1530.. Test accuracy: 0.7828.. 0.5433 s/batch
# Epoch: 8/15.. Loss: 0.1139.. Test accuracy: 0.7746.. 0.5178 s/batch
# Epoch: 8/15.. Loss: 0.1308.. Test accuracy: 0.7633.. 0.4985 s/batch
# Epoch: 8/15.. Loss: 0.1173.. Test accuracy: 0.7797.. 0.5008 s/batch
# Epoch: 8/15.. Loss: 0.1407.. Test accuracy: 0.7748.. 0.5032 s/batch
# Epoch: 8/15.. Loss: 0.1248.. Test accuracy: 0.7746.. 0.4949 s/batch
# Epoch: 8/15.. Loss: 0.1437.. Test accuracy: 0.7898.. 0.5454 s/batch
# Epoch: 8/15.. Loss: 0.1624.. Test accuracy: 0.7756.. 0.5066 s/batch
# Epoch: 8/15.. Loss: 0.1360.. Test accuracy: 0.7799.. 0.5236 s/batch
# Epoch: 8/15.. Loss: 0.1770.. Test accuracy: 0.7619.. 0.5113 s/batch
# Epoch: 8/15.. Loss: 0.1774.. Test accuracy: 0.7803.. 0.5241 s/batch
# Epoch: 8/15.. Loss: 0.1580.. Test accuracy: 0.7678.. 0.5116 s/batch
# Epoch: 8/15.. Loss: 0.1665.. Test accuracy: 0.7721.. 0.4968 s/batch
# Epoch: 8/15.. Loss: 0.1323.. Test accuracy: 0.7645.. 0.4951 s/batch
# Epoch: 8/15.. Loss: 0.1486.. Test accuracy: 0.7736.. 0.4912 s/batch
# Epoch: 8/15.. Loss: 0.1497.. Test accuracy: 0.7873.. 0.5153 s/batch
# Epoch: 8/15.. Loss: 0.1643.. Test accuracy: 0.7859.. 0.5291 s/batch
# Epoch: 8/15.. Loss: 0.1679.. Test accuracy: 0.7762.. 0.5051 s/batch
# Epoch: 8/15.. Loss: 0.1716.. Test accuracy: 0.7932.. 0.5041 s/batch
# Epoch: 8/15.. Loss: 0.1551.. Test accuracy: 0.7850.. 0.5267 s/batch
# Epoch: 9/15.. Loss: 0.1273.. Test accuracy: 0.7732.. 0.3061 s/batch
# Epoch: 9/15.. Loss: 0.0934.. Test accuracy: 0.7896.. 0.4962 s/batch
# Epoch: 9/15.. Loss: 0.0835.. Test accuracy: 0.7812.. 0.5131 s/batch
# Epoch: 9/15.. Loss: 0.0797.. Test accuracy: 0.7867.. 0.5196 s/batch
# Epoch: 9/15.. Loss: 0.0909.. Test accuracy: 0.7756.. 0.5495 s/batch
# Epoch: 9/15.. Loss: 0.0713.. Test accuracy: 0.7688.. 0.5171 s/batch
# Epoch: 9/15.. Loss: 0.0823.. Test accuracy: 0.7639.. 0.5121 s/batch
# Epoch: 9/15.. Loss: 0.1003.. Test accuracy: 0.7791.. 0.5037 s/batch
# Epoch: 9/15.. Loss: 0.1105.. Test accuracy: 0.7762.. 0.4990 s/batch
# Epoch: 9/15.. Loss: 0.0813.. Test accuracy: 0.7754.. 0.5040 s/batch
# Epoch: 9/15.. Loss: 0.0934.. Test accuracy: 0.7637.. 0.4966 s/batch
# Epoch: 9/15.. Loss: 0.0980.. Test accuracy: 0.7846.. 0.8170 s/batch
# Epoch: 9/15.. Loss: 0.1141.. Test accuracy: 0.7820.. 0.8298 s/batch
# Epoch: 9/15.. Loss: 0.0842.. Test accuracy: 0.7750.. 0.8209 s/batch
# Epoch: 9/15.. Loss: 0.0993.. Test accuracy: 0.7664.. 0.8362 s/batch
# Epoch: 9/15.. Loss: 0.1009.. Test accuracy: 0.7783.. 0.8237 s/batch
# Epoch: 9/15.. Loss: 0.0856.. Test accuracy: 0.7805.. 0.8221 s/batch
# Epoch: 9/15.. Loss: 0.0806.. Test accuracy: 0.7748.. 0.8296 s/batch
# Epoch: 9/15.. Loss: 0.0968.. Test accuracy: 0.7873.. 0.8305 s/batch
# Epoch: 9/15.. Loss: 0.1122.. Test accuracy: 0.7689.. 0.8271 s/batch
# Epoch: 9/15.. Loss: 0.0977.. Test accuracy: 0.7852.. 0.8444 s/batch
# Epoch: 9/15.. Loss: 0.0820.. Test accuracy: 0.7676.. 0.8485 s/batch
# Epoch: 9/15.. Loss: 0.0896.. Test accuracy: 0.7713.. 0.8305 s/batch
# Epoch: 9/15.. Loss: 0.0957.. Test accuracy: 0.7660.. 0.8410 s/batch
# Epoch: 9/15.. Loss: 0.1062.. Test accuracy: 0.7799.. 0.8050 s/batch
# Epoch: 9/15.. Loss: 0.0923.. Test accuracy: 0.7803.. 0.8134 s/batch
# Epoch: 9/15.. Loss: 0.1060.. Test accuracy: 0.7742.. 0.8133 s/batch
# Epoch: 9/15.. Loss: 0.1165.. Test accuracy: 0.7775.. 0.4782 s/batch
# Epoch: 9/15.. Loss: 0.1120.. Test accuracy: 0.7760.. 0.4789 s/batch
# Epoch: 9/15.. Loss: 0.1206.. Test accuracy: 0.7684.. 0.4877 s/batch
# Epoch: 9/15.. Loss: 0.1048.. Test accuracy: 0.7588.. 0.4846 s/batch
# Epoch: 9/15.. Loss: 0.1216.. Test accuracy: 0.7715.. 0.5079 s/batch
# Epoch: 9/15.. Loss: 0.1243.. Test accuracy: 0.7703.. 0.4869 s/batch
# Epoch: 9/15.. Loss: 0.0961.. Test accuracy: 0.7705.. 0.4811 s/batch
# Epoch: 9/15.. Loss: 0.1042.. Test accuracy: 0.7877.. 0.4825 s/batch
# Epoch: 9/15.. Loss: 0.1372.. Test accuracy: 0.7750.. 0.4836 s/batch
# Epoch: 9/15.. Loss: 0.1310.. Test accuracy: 0.7809.. 0.4975 s/batch
# Epoch: 9/15.. Loss: 0.1403.. Test accuracy: 0.7723.. 0.4893 s/batch
# Epoch: 10/15.. Loss: 0.1082.. Test accuracy: 0.7748.. 0.1487 s/batch
# Epoch: 10/15.. Loss: 0.0696.. Test accuracy: 0.7832.. 0.4889 s/batch
# Epoch: 10/15.. Loss: 0.0660.. Test accuracy: 0.7926.. 0.5024 s/batch
# Epoch: 10/15.. Loss: 0.0632.. Test accuracy: 0.7742.. 0.4882 s/batch
# Epoch: 10/15.. Loss: 0.0640.. Test accuracy: 0.7768.. 0.4875 s/batch
# Epoch: 10/15.. Loss: 0.0659.. Test accuracy: 0.7775.. 0.4895 s/batch
# Epoch: 10/15.. Loss: 0.0683.. Test accuracy: 0.7791.. 0.4927 s/batch
# Epoch: 10/15.. Loss: 0.0829.. Test accuracy: 0.7773.. 0.5591 s/batch
# Epoch: 10/15.. Loss: 0.0592.. Test accuracy: 0.7629.. 0.6564 s/batch
# Epoch: 10/15.. Loss: 0.0775.. Test accuracy: 0.7695.. 0.6869 s/batch
# Epoch: 10/15.. Loss: 0.0571.. Test accuracy: 0.7590.. 0.5731 s/batch
# Epoch: 10/15.. Loss: 0.0809.. Test accuracy: 0.7715.. 0.5133 s/batch
# Epoch: 10/15.. Loss: 0.0833.. Test accuracy: 0.7707.. 0.5286 s/batch
# Epoch: 10/15.. Loss: 0.0766.. Test accuracy: 0.7703.. 0.5359 s/batch
# Epoch: 10/15.. Loss: 0.0747.. Test accuracy: 0.7805.. 0.5139 s/batch
# Epoch: 10/15.. Loss: 0.0939.. Test accuracy: 0.7822.. 0.5381 s/batch
# Epoch: 10/15.. Loss: 0.0739.. Test accuracy: 0.7877.. 0.5536 s/batch
# Epoch: 10/15.. Loss: 0.0899.. Test accuracy: 0.7727.. 0.5596 s/batch
# Epoch: 10/15.. Loss: 0.0897.. Test accuracy: 0.7787.. 0.5570 s/batch
# Epoch: 10/15.. Loss: 0.1024.. Test accuracy: 0.7768.. 0.5530 s/batch
# Epoch: 10/15.. Loss: 0.0814.. Test accuracy: 0.7738.. 0.5660 s/batch
# Epoch: 10/15.. Loss: 0.1022.. Test accuracy: 0.7893.. 0.5145 s/batch
# Epoch: 10/15.. Loss: 0.1155.. Test accuracy: 0.7641.. 0.5035 s/batch
# Epoch: 10/15.. Loss: 0.1046.. Test accuracy: 0.7844.. 0.5813 s/batch
# Epoch: 10/15.. Loss: 0.0891.. Test accuracy: 0.7828.. 0.5330 s/batch
# Epoch: 10/15.. Loss: 0.0979.. Test accuracy: 0.7854.. 0.6159 s/batch
# Epoch: 10/15.. Loss: 0.0987.. Test accuracy: 0.7781.. 0.5467 s/batch
# Epoch: 10/15.. Loss: 0.0871.. Test accuracy: 0.7531.. 0.5853 s/batch
# Epoch: 10/15.. Loss: 0.1212.. Test accuracy: 0.7836.. 0.5102 s/batch
# Epoch: 10/15.. Loss: 0.0958.. Test accuracy: 0.7660.. 0.5097 s/batch
# Epoch: 10/15.. Loss: 0.1082.. Test accuracy: 0.7777.. 0.5118 s/batch
# Epoch: 10/15.. Loss: 0.1019.. Test accuracy: 0.7857.. 0.6480 s/batch
# Epoch: 10/15.. Loss: 0.0910.. Test accuracy: 0.7711.. 0.5645 s/batch
# Epoch: 10/15.. Loss: 0.0942.. Test accuracy: 0.7777.. 0.5370 s/batch
# Epoch: 10/15.. Loss: 0.0966.. Test accuracy: 0.7570.. 0.5105 s/batch
# Epoch: 10/15.. Loss: 0.1063.. Test accuracy: 0.7637.. 0.5738 s/batch
# Epoch: 10/15.. Loss: 0.0699.. Test accuracy: 0.7695.. 0.5590 s/batch
# Epoch: 10/15.. Loss: 0.0990.. Test accuracy: 0.7633.. 0.5145 s/batch
# Epoch: 10/15.. Loss: 0.0886.. Test accuracy: 0.7764.. 0.5601 s/batch
# Epoch: 11/15.. Loss: 0.0532.. Test accuracy: 0.7875.. 0.5945 s/batch
# Epoch: 11/15.. Loss: 0.0548.. Test accuracy: 0.7770.. 0.6402 s/batch
# Epoch: 11/15.. Loss: 0.0496.. Test accuracy: 0.7781.. 0.5801 s/batch
# Epoch: 11/15.. Loss: 0.0475.. Test accuracy: 0.7945.. 0.5114 s/batch
# Epoch: 11/15.. Loss: 0.0602.. Test accuracy: 0.7912.. 0.5177 s/batch
# Epoch: 11/15.. Loss: 0.0517.. Test accuracy: 0.7775.. 0.5300 s/batch
# Epoch: 11/15.. Loss: 0.0403.. Test accuracy: 0.7754.. 0.5175 s/batch
# Epoch: 11/15.. Loss: 0.0562.. Test accuracy: 0.7900.. 0.5082 s/batch
# Epoch: 11/15.. Loss: 0.0528.. Test accuracy: 0.7754.. 0.4973 s/batch
# Epoch: 11/15.. Loss: 0.0606.. Test accuracy: 0.7781.. 0.5050 s/batch
# Epoch: 11/15.. Loss: 0.0472.. Test accuracy: 0.7893.. 0.5075 s/batch
# Epoch: 11/15.. Loss: 0.0565.. Test accuracy: 0.7838.. 0.4996 s/batch
# Epoch: 11/15.. Loss: 0.0501.. Test accuracy: 0.7748.. 0.5086 s/batch
# Epoch: 11/15.. Loss: 0.0472.. Test accuracy: 0.7811.. 0.5505 s/batch
# Epoch: 11/15.. Loss: 0.0511.. Test accuracy: 0.7711.. 0.5054 s/batch
# Epoch: 11/15.. Loss: 0.0523.. Test accuracy: 0.7803.. 0.5275 s/batch
# Epoch: 11/15.. Loss: 0.0513.. Test accuracy: 0.7891.. 0.4967 s/batch
# Epoch: 11/15.. Loss: 0.0547.. Test accuracy: 0.7805.. 0.5177 s/batch
# Epoch: 11/15.. Loss: 0.0506.. Test accuracy: 0.7773.. 0.5162 s/batch
# Epoch: 11/15.. Loss: 0.0562.. Test accuracy: 0.7703.. 0.5434 s/batch
# Epoch: 11/15.. Loss: 0.0616.. Test accuracy: 0.7885.. 0.5118 s/batch
# Epoch: 11/15.. Loss: 0.0605.. Test accuracy: 0.7852.. 0.5316 s/batch
# Epoch: 11/15.. Loss: 0.0718.. Test accuracy: 0.7736.. 0.5479 s/batch
# Epoch: 11/15.. Loss: 0.0821.. Test accuracy: 0.7914.. 0.5180 s/batch
# Epoch: 11/15.. Loss: 0.0781.. Test accuracy: 0.7865.. 0.5269 s/batch
# Epoch: 11/15.. Loss: 0.0607.. Test accuracy: 0.7799.. 0.5020 s/batch
# Epoch: 11/15.. Loss: 0.0691.. Test accuracy: 0.7828.. 0.4941 s/batch
# Epoch: 11/15.. Loss: 0.0993.. Test accuracy: 0.7785.. 0.4968 s/batch
# Epoch: 11/15.. Loss: 0.0911.. Test accuracy: 0.7736.. 0.5028 s/batch
# Epoch: 11/15.. Loss: 0.0653.. Test accuracy: 0.7742.. 0.4982 s/batch
# Epoch: 11/15.. Loss: 0.0760.. Test accuracy: 0.7666.. 0.5152 s/batch
# Epoch: 11/15.. Loss: 0.0819.. Test accuracy: 0.7701.. 0.5108 s/batch
# Epoch: 11/15.. Loss: 0.0725.. Test accuracy: 0.7746.. 0.4982 s/batch
# Epoch: 11/15.. Loss: 0.0813.. Test accuracy: 0.7686.. 0.4960 s/batch
# Epoch: 11/15.. Loss: 0.0806.. Test accuracy: 0.7629.. 0.4970 s/batch
# Epoch: 11/15.. Loss: 0.0919.. Test accuracy: 0.7771.. 0.5014 s/batch
# Epoch: 11/15.. Loss: 0.0940.. Test accuracy: 0.7809.. 0.5029 s/batch
# Epoch: 11/15.. Loss: 0.0746.. Test accuracy: 0.7818.. 0.4970 s/batch
# Epoch: 12/15.. Loss: 0.0685.. Test accuracy: 0.7689.. 0.3508 s/batch
# Epoch: 12/15.. Loss: 0.0619.. Test accuracy: 0.7641.. 0.5003 s/batch
# Epoch: 12/15.. Loss: 0.0589.. Test accuracy: 0.7639.. 0.5031 s/batch
# Epoch: 12/15.. Loss: 0.0522.. Test accuracy: 0.7695.. 0.5006 s/batch
# Epoch: 12/15.. Loss: 0.0525.. Test accuracy: 0.7764.. 0.4997 s/batch
# Epoch: 12/15.. Loss: 0.0481.. Test accuracy: 0.7775.. 0.4935 s/batch
# Epoch: 12/15.. Loss: 0.0425.. Test accuracy: 0.7697.. 0.5000 s/batch
# Epoch: 12/15.. Loss: 0.0379.. Test accuracy: 0.7654.. 0.5022 s/batch
# Epoch: 12/15.. Loss: 0.0437.. Test accuracy: 0.7641.. 0.4986 s/batch
# Epoch: 12/15.. Loss: 0.0411.. Test accuracy: 0.7842.. 0.5024 s/batch
# Epoch: 12/15.. Loss: 0.0322.. Test accuracy: 0.7781.. 0.4930 s/batch
# Epoch: 12/15.. Loss: 0.0317.. Test accuracy: 0.7809.. 0.4992 s/batch
# Epoch: 12/15.. Loss: 0.0407.. Test accuracy: 0.7695.. 0.4995 s/batch
# Epoch: 12/15.. Loss: 0.0456.. Test accuracy: 0.7850.. 0.4945 s/batch
# Epoch: 12/15.. Loss: 0.0436.. Test accuracy: 0.7729.. 0.5001 s/batch
# Epoch: 12/15.. Loss: 0.0352.. Test accuracy: 0.7734.. 0.4960 s/batch
# Epoch: 12/15.. Loss: 0.0522.. Test accuracy: 0.7697.. 0.4970 s/batch
# Epoch: 12/15.. Loss: 0.0423.. Test accuracy: 0.7791.. 0.5530 s/batch
# Epoch: 12/15.. Loss: 0.0453.. Test accuracy: 0.7783.. 0.5776 s/batch
# Epoch: 12/15.. Loss: 0.0413.. Test accuracy: 0.7748.. 0.4994 s/batch
# Epoch: 12/15.. Loss: 0.0493.. Test accuracy: 0.7656.. 0.4982 s/batch
# Epoch: 12/15.. Loss: 0.0531.. Test accuracy: 0.7723.. 0.5001 s/batch
# Epoch: 12/15.. Loss: 0.0477.. Test accuracy: 0.7846.. 0.4962 s/batch
# Epoch: 12/15.. Loss: 0.0454.. Test accuracy: 0.7777.. 0.4991 s/batch
# Epoch: 12/15.. Loss: 0.0646.. Test accuracy: 0.7834.. 0.4966 s/batch
# Epoch: 12/15.. Loss: 0.0580.. Test accuracy: 0.7793.. 0.5040 s/batch
# Epoch: 12/15.. Loss: 0.0639.. Test accuracy: 0.7643.. 0.4957 s/batch
# Epoch: 12/15.. Loss: 0.0546.. Test accuracy: 0.7654.. 0.4947 s/batch
# Epoch: 12/15.. Loss: 0.0404.. Test accuracy: 0.7680.. 0.4993 s/batch
# Epoch: 12/15.. Loss: 0.0534.. Test accuracy: 0.7791.. 0.4907 s/batch
# Epoch: 12/15.. Loss: 0.0619.. Test accuracy: 0.7633.. 0.5108 s/batch
# Epoch: 12/15.. Loss: 0.0828.. Test accuracy: 0.7656.. 0.5012 s/batch
# Epoch: 12/15.. Loss: 0.0654.. Test accuracy: 0.7748.. 0.4946 s/batch
# Epoch: 12/15.. Loss: 0.0735.. Test accuracy: 0.7691.. 0.5005 s/batch
# Epoch: 12/15.. Loss: 0.0688.. Test accuracy: 0.7648.. 0.5366 s/batch
# Epoch: 12/15.. Loss: 0.0925.. Test accuracy: 0.7641.. 0.5221 s/batch
# Epoch: 12/15.. Loss: 0.0645.. Test accuracy: 0.7770.. 0.4975 s/batch
# Epoch: 12/15.. Loss: 0.0859.. Test accuracy: 0.7785.. 0.4969 s/batch
# Epoch: 13/15.. Loss: 0.0754.. Test accuracy: 0.7598.. 0.2016 s/batch
# Epoch: 13/15.. Loss: 0.0540.. Test accuracy: 0.7557.. 0.4937 s/batch
# Epoch: 13/15.. Loss: 0.0492.. Test accuracy: 0.7602.. 0.5042 s/batch
# Epoch: 13/15.. Loss: 0.0650.. Test accuracy: 0.7754.. 0.5176 s/batch
# Epoch: 13/15.. Loss: 0.0351.. Test accuracy: 0.7744.. 0.6216 s/batch
# Epoch: 13/15.. Loss: 0.0507.. Test accuracy: 0.7711.. 0.6074 s/batch
# Epoch: 13/15.. Loss: 0.0564.. Test accuracy: 0.7768.. 0.5228 s/batch
# Epoch: 13/15.. Loss: 0.0452.. Test accuracy: 0.7771.. 0.5049 s/batch
# Epoch: 13/15.. Loss: 0.0479.. Test accuracy: 0.7508.. 0.5027 s/batch
# Epoch: 13/15.. Loss: 0.0394.. Test accuracy: 0.7826.. 0.4969 s/batch
# Epoch: 13/15.. Loss: 0.0479.. Test accuracy: 0.7783.. 0.5016 s/batch
# Epoch: 13/15.. Loss: 0.0337.. Test accuracy: 0.7754.. 0.5036 s/batch
# Epoch: 13/15.. Loss: 0.0515.. Test accuracy: 0.7707.. 0.5134 s/batch
# Epoch: 13/15.. Loss: 0.0418.. Test accuracy: 0.7689.. 0.5498 s/batch
# Epoch: 13/15.. Loss: 0.0343.. Test accuracy: 0.7840.. 0.4990 s/batch
# Epoch: 13/15.. Loss: 0.0376.. Test accuracy: 0.7908.. 0.5071 s/batch
# Epoch: 13/15.. Loss: 0.0380.. Test accuracy: 0.7937.. 0.5100 s/batch
# Epoch: 13/15.. Loss: 0.0521.. Test accuracy: 0.7779.. 0.4941 s/batch
# Epoch: 13/15.. Loss: 0.0402.. Test accuracy: 0.7717.. 0.5016 s/batch
# Epoch: 13/15.. Loss: 0.0436.. Test accuracy: 0.7855.. 0.5047 s/batch
# Epoch: 13/15.. Loss: 0.0459.. Test accuracy: 0.7834.. 0.5007 s/batch
# Epoch: 13/15.. Loss: 0.0369.. Test accuracy: 0.7719.. 0.5023 s/batch
# Epoch: 13/15.. Loss: 0.0302.. Test accuracy: 0.7879.. 0.4974 s/batch
# Epoch: 13/15.. Loss: 0.0257.. Test accuracy: 0.8076.. 0.4940 s/batch
# Epoch: 13/15.. Loss: 0.0411.. Test accuracy: 0.7971.. 0.4954 s/batch
# Epoch: 13/15.. Loss: 0.0395.. Test accuracy: 0.7758.. 0.5216 s/batch
# Epoch: 13/15.. Loss: 0.0332.. Test accuracy: 0.7857.. 0.4997 s/batch
# Epoch: 13/15.. Loss: 0.0354.. Test accuracy: 0.7850.. 0.5028 s/batch
# Epoch: 13/15.. Loss: 0.0363.. Test accuracy: 0.7695.. 0.4983 s/batch
# Epoch: 13/15.. Loss: 0.0383.. Test accuracy: 0.7701.. 0.5026 s/batch
# Epoch: 13/15.. Loss: 0.0447.. Test accuracy: 0.7787.. 0.4970 s/batch
# Epoch: 13/15.. Loss: 0.0502.. Test accuracy: 0.7848.. 0.4959 s/batch
# Epoch: 13/15.. Loss: 0.0460.. Test accuracy: 0.7686.. 0.5096 s/batch
# Epoch: 13/15.. Loss: 0.0593.. Test accuracy: 0.7791.. 0.5404 s/batch
# Epoch: 13/15.. Loss: 0.0397.. Test accuracy: 0.7732.. 0.4995 s/batch
# Epoch: 13/15.. Loss: 0.0696.. Test accuracy: 0.7850.. 0.5008 s/batch
# Epoch: 13/15.. Loss: 0.0558.. Test accuracy: 0.7766.. 0.4960 s/batch
# Epoch: 13/15.. Loss: 0.0554.. Test accuracy: 0.7809.. 0.5061 s/batch
# Epoch: 14/15.. Loss: 0.0617.. Test accuracy: 0.7717.. 0.0501 s/batch
# Epoch: 14/15.. Loss: 0.0305.. Test accuracy: 0.7682.. 0.4978 s/batch
# Epoch: 14/15.. Loss: 0.0435.. Test accuracy: 0.7656.. 0.4943 s/batch
# Epoch: 14/15.. Loss: 0.0399.. Test accuracy: 0.7807.. 0.4953 s/batch
# Epoch: 14/15.. Loss: 0.0322.. Test accuracy: 0.7645.. 0.4971 s/batch
# Epoch: 14/15.. Loss: 0.0286.. Test accuracy: 0.7768.. 0.5010 s/batch
# Epoch: 14/15.. Loss: 0.0247.. Test accuracy: 0.7834.. 0.5499 s/batch
# Epoch: 14/15.. Loss: 0.0294.. Test accuracy: 0.7617.. 0.5439 s/batch
# Epoch: 14/15.. Loss: 0.0226.. Test accuracy: 0.7652.. 0.5476 s/batch
# Epoch: 14/15.. Loss: 0.0254.. Test accuracy: 0.7717.. 0.5604 s/batch
# Epoch: 14/15.. Loss: 0.0261.. Test accuracy: 0.7723.. 0.5466 s/batch
# Epoch: 14/15.. Loss: 0.0241.. Test accuracy: 0.7941.. 0.5222 s/batch
# Epoch: 14/15.. Loss: 0.0311.. Test accuracy: 0.7799.. 0.5022 s/batch
# Epoch: 14/15.. Loss: 0.0294.. Test accuracy: 0.7822.. 0.5083 s/batch
# Epoch: 14/15.. Loss: 0.0268.. Test accuracy: 0.7758.. 0.5148 s/batch
# Epoch: 14/15.. Loss: 0.0318.. Test accuracy: 0.7729.. 0.5297 s/batch
# Epoch: 14/15.. Loss: 0.0319.. Test accuracy: 0.7943.. 0.4989 s/batch
# Epoch: 14/15.. Loss: 0.0268.. Test accuracy: 0.7770.. 0.5033 s/batch
# Epoch: 14/15.. Loss: 0.0294.. Test accuracy: 0.7699.. 0.4951 s/batch
# Epoch: 14/15.. Loss: 0.0225.. Test accuracy: 0.7877.. 0.5191 s/batch
# Epoch: 14/15.. Loss: 0.0289.. Test accuracy: 0.7748.. 0.5866 s/batch
# Epoch: 14/15.. Loss: 0.0388.. Test accuracy: 0.7719.. 0.5723 s/batch
# Epoch: 14/15.. Loss: 0.0205.. Test accuracy: 0.7766.. 0.5147 s/batch
# Epoch: 14/15.. Loss: 0.0365.. Test accuracy: 0.7869.. 0.5836 s/batch
# Epoch: 14/15.. Loss: 0.0345.. Test accuracy: 0.7723.. 0.5801 s/batch
# Epoch: 14/15.. Loss: 0.0239.. Test accuracy: 0.7680.. 0.5464 s/batch
# Epoch: 14/15.. Loss: 0.0223.. Test accuracy: 0.7789.. 0.5245 s/batch
# Epoch: 14/15.. Loss: 0.0253.. Test accuracy: 0.7850.. 0.5156 s/batch
# Epoch: 14/15.. Loss: 0.0245.. Test accuracy: 0.7760.. 0.5154 s/batch
# Epoch: 14/15.. Loss: 0.0382.. Test accuracy: 0.7850.. 0.5456 s/batch
# Epoch: 14/15.. Loss: 0.0325.. Test accuracy: 0.7650.. 0.5405 s/batch
# Epoch: 14/15.. Loss: 0.0363.. Test accuracy: 0.7676.. 0.5122 s/batch
# Epoch: 14/15.. Loss: 0.0414.. Test accuracy: 0.7816.. 0.5350 s/batch
# Epoch: 14/15.. Loss: 0.0457.. Test accuracy: 0.7895.. 0.5375 s/batch
# Epoch: 14/15.. Loss: 0.0372.. Test accuracy: 0.7830.. 0.5196 s/batch
# Epoch: 14/15.. Loss: 0.0345.. Test accuracy: 0.7764.. 0.5230 s/batch
# Epoch: 14/15.. Loss: 0.0368.. Test accuracy: 0.7637.. 0.5614 s/batch
# Epoch: 14/15.. Loss: 0.0361.. Test accuracy: 0.7809.. 0.5098 s/batch
# Epoch: 14/15.. Loss: 0.0301.. Test accuracy: 0.7748.. 0.5052 s/batch
# Epoch: 15/15.. Loss: 0.0325.. Test accuracy: 0.7842.. 0.4053 s/batch
# Epoch: 15/15.. Loss: 0.0239.. Test accuracy: 0.7906.. 0.5033 s/batch
# Epoch: 15/15.. Loss: 0.0315.. Test accuracy: 0.7836.. 0.4985 s/batch
# Epoch: 15/15.. Loss: 0.0224.. Test accuracy: 0.7943.. 0.5038 s/batch
# Epoch: 15/15.. Loss: 0.0294.. Test accuracy: 0.7812.. 0.5013 s/batch
# Epoch: 15/15.. Loss: 0.0137.. Test accuracy: 0.7693.. 0.5264 s/batch
# Epoch: 15/15.. Loss: 0.0182.. Test accuracy: 0.7930.. 0.5055 s/batch
# Epoch: 15/15.. Loss: 0.0188.. Test accuracy: 0.7883.. 0.5070 s/batch
# Epoch: 15/15.. Loss: 0.0191.. Test accuracy: 0.7822.. 0.5133 s/batch
# Epoch: 15/15.. Loss: 0.0245.. Test accuracy: 0.7730.. 0.5002 s/batch
# Epoch: 15/15.. Loss: 0.0169.. Test accuracy: 0.7803.. 0.4987 s/batch
# Epoch: 15/15.. Loss: 0.0279.. Test accuracy: 0.7852.. 0.4994 s/batch
# Epoch: 15/15.. Loss: 0.0135.. Test accuracy: 0.7766.. 0.5069 s/batch
# Epoch: 15/15.. Loss: 0.0153.. Test accuracy: 0.7826.. 0.5071 s/batch
# Epoch: 15/15.. Loss: 0.0182.. Test accuracy: 0.7820.. 0.4992 s/batch
# Epoch: 15/15.. Loss: 0.0204.. Test accuracy: 0.7803.. 0.5045 s/batch
# Epoch: 15/15.. Loss: 0.0164.. Test accuracy: 0.7762.. 0.5102 s/batch
# Epoch: 15/15.. Loss: 0.0162.. Test accuracy: 0.7848.. 0.4984 s/batch
# Epoch: 15/15.. Loss: 0.0208.. Test accuracy: 0.7775.. 0.4979 s/batch
# Epoch: 15/15.. Loss: 0.0199.. Test accuracy: 0.7832.. 0.5010 s/batch
# Epoch: 15/15.. Loss: 0.0162.. Test accuracy: 0.7871.. 0.5018 s/batch
# Epoch: 15/15.. Loss: 0.0266.. Test accuracy: 0.7965.. 0.5096 s/batch
# Epoch: 15/15.. Loss: 0.0118.. Test accuracy: 0.7873.. 0.4989 s/batch
# Epoch: 15/15.. Loss: 0.0137.. Test accuracy: 0.7895.. 0.5023 s/batch
# Epoch: 15/15.. Loss: 0.0122.. Test accuracy: 0.7895.. 0.5000 s/batch
# Epoch: 15/15.. Loss: 0.0180.. Test accuracy: 0.7818.. 0.5286 s/batch
# Epoch: 15/15.. Loss: 0.0181.. Test accuracy: 0.7904.. 0.5105 s/batch
# Epoch: 15/15.. Loss: 0.0277.. Test accuracy: 0.7855.. 0.4979 s/batch
# Epoch: 15/15.. Loss: 0.0188.. Test accuracy: 0.7752.. 0.4996 s/batch
# Epoch: 15/15.. Loss: 0.0149.. Test accuracy: 0.7807.. 0.4992 s/batch
# Epoch: 15/15.. Loss: 0.0215.. Test accuracy: 0.8051.. 0.5052 s/batch
# Epoch: 15/15.. Loss: 0.0163.. Test accuracy: 0.7826.. 0.4996 s/batch
# Epoch: 15/15.. Loss: 0.0205.. Test accuracy: 0.7832.. 0.5122 s/batch
# Epoch: 15/15.. Loss: 0.0328.. Test accuracy: 0.7893.. 0.5143 s/batch
# Epoch: 15/15.. Loss: 0.0235.. Test accuracy: 0.7797.. 0.5026 s/batch
# Epoch: 15/15.. Loss: 0.0219.. Test accuracy: 0.7777.. 0.4991 s/batch
# Epoch: 15/15.. Loss: 0.0194.. Test accuracy: 0.7816.. 0.5031 s/batch
# Epoch: 15/15.. Loss: 0.0260.. Test accuracy: 0.7920.. 0.4986 s/batch

# %% [markdown]
# Save best trained model.

# %%
torch.save(net.state_dict(), 'model_vgg_half.ckpt')
